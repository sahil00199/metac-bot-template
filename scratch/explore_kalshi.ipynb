# %%
import requests
import numpy as np
import pandas as pd

# %%
BASE = "https://api.elections.kalshi.com/trade-api/v2/markets"

params = {"limit": 1000, "status": "open", "mve_filter": "exclude"}  # max per page
all_markets = []
cursor = None

while True:
    if cursor:
        params["cursor"] = cursor
    resp = requests.get(BASE, params=params)
    resp.raise_for_status()
    data = resp.json()

    all_markets.extend(data["markets"])
    cursor = data.get("cursor")
    if not cursor:  # no more pages
        break
    print(f"Loaded {len(all_markets)} so far")
print(len(all_markets), "markets fetched")
# Out:
# Loaded 1000 so far
# Loaded 2000 so far
# Loaded 3000 so far
# Loaded 4000 so far
# Loaded 5000 so far
# Loaded 6000 so far
# Loaded 7000 so far
# Loaded 8000 so far
# Loaded 9000 so far
# Loaded 10000 so far
# Loaded 11000 so far
# Loaded 12000 so far
# Loaded 13000 so far
# Loaded 14000 so far
# Loaded 15000 so far
# Loaded 16000 so far
# Loaded 17000 so far
# Loaded 18000 so far
# Loaded 19000 so far
# Loaded 20000 so far
# 20889 markets fetched

# %%
def market_is_multivariate(market):
    return market.get("mve_collection_ticker") not in (None, "", 0)

SPORT_PREFIXES = (
    "KXNFL",
    "KXNHL",
    "KXNBA",
    "KXNCAA",
    "KXNCBB",
    "KXCRICKET",
    "KXSERIEA",
    "KXLEADERNFL",
    "KXEPL",
    # add more as you discover them
)

def is_sports_market(m: dict) -> bool:
    event_ticker = m.get("event_ticker", "")
    is_sports = event_ticker.startswith(SPORT_PREFIXES)
    is_sports = is_sports or event_ticker.split('-')[0].endswith(('GAME', 'CUP', 'MATCH'))
    return is_sports


liquid_markets = [market for market in all_markets if market['volume_24h'] > -1]
print(f"Of {len(all_markets)} markets, {len(liquid_markets)} markets are liquid")
# pd.Series([market_is_multivariate(market) for market in all_markets]).value_counts()
# Out:
# Of 20889 markets, 20889 markets are liquid

# %%
display(pd.Series([is_sports_market(market) for market in liquid_markets]).value_counts())
event_tickers = [market['event_ticker'].split('-')[0] for market in liquid_markets]
print(f"Of {len(event_tickers)} events, there are {len(np.unique(event_tickers))} unique ones")
# Out:
# False    14241
# True      6648
# Name: count, dtype: int64
# Of 20889 events, there are 1774 unique ones

# %%
market_df = pd.DataFrame(all_markets)
market_df['event_proxy'] = market_df.event_ticker.map(lambda x : x.split('-')[0])
market_df['is_sports_market'] = market_df.apply(is_sports_market, axis = 1)
market_df['volume_bucket'] = pd.cut(market_df.volume_24h, [-1, 0, 1, 10, 100, 1000, 10000, 1e9])
display_df = market_df.groupby('is_sports_market').volume_bucket.value_counts().unstack(0)
display_df.loc['total'] = display_df.sum(axis = 0)
display_df
# Out:
# is_sports_market         False  True
# volume_bucket
# (-1.0, 0.0]              10097   4336
# (0.0, 1.0]                 137     82
# (1.0, 10.0]                423    297
# (10.0, 100.0]             1183    641
# (100.0, 1000.0]           1531    734
# (1000.0, 10000.0]          683    421
# (10000.0, 1000000000.0]    187    137
# total                    14241   6648

# %%
market_df['close_time'] = pd.to_datetime(market_df.close_time)
market_df[(~market_df.is_sports_market) & (market_df.volume_24h > -1)].drop_duplicates('event_proxy', keep = 'last').close_time.describe(percentiles = np.arange(0, 1, 0.1))
# Out:
# count                                   1591
# mean     2027-07-10 17:58:23.775612672+00:00
# min                2026-01-02 07:45:00+00:00
# 0%                 2026-01-02 07:45:00+00:00
# 10%                2026-02-01 15:00:00+00:00
# 20%                2026-06-02 02:00:00+00:00
# 30%                2026-11-03 15:00:00+00:00
# 40%                2027-01-01 04:59:00+00:00
# 50%                2027-01-01 15:00:00+00:00
# 60%                2027-02-01 15:00:00+00:00
# 70%                2027-11-03 15:00:00+00:00
# 80%                2027-11-03 15:00:00+00:00
# 90%                2029-01-20 15:00:00+00:00
# max                2099-08-01 04:59:00+00:00
# Name: close_time, dtype: object

# %%
jan_markets = market_df[(~market_df.is_sports_market) & (market_df.volume_24h > -1) & (market_df.close_time < pd.Timestamp('2026-01-31').tz_localize("America/New_York"))].drop_duplicates('event_proxy', keep = 'last')
print(len(jan_markets))
for _, row in jan_markets.iterrows():
    print(row.title, "|", row.event_ticker)
# Out:
# 132
# BTC price up in next 15 mins? | KXBTC15M-26JAN020245
# ETH price up in next 15 mins? | KXETH15M-26JAN020245
# Top USA Song on Spotify on Jan 2, 2026? | KXSPOTIFYD-26JAN02
# Top Global Song on Spotify on Jan 2, 2026? | KXSPOTIFYGLOBALD-26JAN02
# Will the runner-up top Song on Jan 2, 2026 be 4 Raws? | KXSPOTIFY2D-26JAN02
# Will the high temp in Chicago be 24-25° on Jan 2, 2026? | KXHIGHCHI-26JAN02
# Will the **high temp in Miami** be 69-70° on Jan 2, 2026? | KXHIGHMIA-26JAN02
# Will the **high temp in Austin** be 84-85° on Jan 2, 2026? | KXHIGHAUS-26JAN02
# Will the **high temp in Philadelphia** be 33-34° on Jan 2, 2026? | KXHIGHPHIL-26JAN02
# Will the **high temp in NYC** be 28-29° on Jan 2, 2026? | KXHIGHNY-26JAN02
# Will the **high temp in Denver** be 57-58° on Jan 2, 2026? | KXHIGHDEN-26JAN02
# Will the minimum temperature be  32-33° on Jan 2, 2026? | KXLOWTDEN-26JAN02
# Will the minimum temperature be  46-47° on Jan 2, 2026? | KXLOWTMIA-26JAN02
# Will the minimum temperature be  17-18° on Jan 2, 2026? | KXLOWTNYC-26JAN02
# Will the minimum temperature be  16-17° on Jan 2, 2026? | KXLOWTPHIL-26JAN02
# Will the minimum temperature be  51-52° on Jan 2, 2026? | KXLOWTAUS-26JAN02
# Will the minimum temperature be  10-11° on Jan 2, 2026? | KXLOWTCHI-26JAN02
# Shiba Inu price  on Jan 2, 2026? | KXSHIBAD-26JAN0217
# Shiba Inu price range  on Jan 2, 2026? | KXSHIBA-26JAN0217
# Will it **rain** in New York City on Friday? | KXRAINNYC-26JAN02
# Will the S&P 500 be above 6074.9999 on Jan 2, 2026 at 4pm EST? | KXINXU-26JAN02H1600
# Will the Nasdaq-100 be above 22199.99 at the end of Jan 2, 2026 at 4pm EST? | KXNASDAQ100U-26JAN02H1600
# Will CPI Core rise more than 0.0% in December? | KXCPICORE-25DECT
# How many initial jobless claims will there be the week ending Jan 3, 2026? | KXJOBLESSCLAIMS-26JAN08
# Top Artist on Weekly Top Artists USA on Jan 8, 2026? | KXSPOTIFYARTISTW-26JAN08
# Top Song on Weekly Top Songs USA on Jan 8, 2026? | KXSPOTIFYW-26JAN08
# Top Album on Weekly Top Albums USA on Jan 8, 2026? | KXSPOTIFYALBUMW-26JAN08
# Will the **high temp in LA** be 61-62° on Jan 1, 2026? | KXHIGHLAX-26JAN01
# Will the minimum temperature be  51-52° on Jan 1, 2026? | KXLOWTLAX-26JAN01
# What will Alexandria Ocasio-Cortez say during ceremonial inauguration at City Hall on January 1st? | KXAOCMENTION-26JAN02
# Will xAI release Grok 4.2 before Jan 5, 2026? | KXGROK-GROK4.2
# Will the #1 Show on Netflix have At least 10 million views? | KXNETFLIXTOPVIEWSTV-26
# #2 US Netflix Show on Jan 5, 2026? | KXNETFLIXRANKSHOWRUNNERUP-26JAN05
# #2 Global Netflix Movie on Jan 5, 2026? | KXNETFLIXRANKMOVIEGLOBAL2-26JAN05
# Top US Netflix Show on Jan 5, 2026? | KXNETFLIXRANKSHOW-26JAN05
# Top Global Netflix Show on Jan 5, 2026? | KXNETFLIXRANKSHOWGLOBAL-26JAN05
# #2 Global Netflix Show on Jan 5, 2026? | KXNETFLIXRANKSHOWGLOBAL2-26JAN05
# #2 US Netflix Movie on Jan 5, 2026? | KXNETFLIXRANKMOVIERUNNERUP-26JAN05
# Top US Netflix Movie on Jan 5, 2026? | KXNETFLIXRANKMOVIE-26JAN05
# Top Global Netflix Movie on Jan 5, 2026? | KXNETFLIXRANKMOVIEGLOBAL-26JAN05
# Will any individual in connection with the Minnesota daycare fraud investigations be charged with a fraud, theft, embezzlement, bribery, money laundering, or conspiracy crime before Jan 15, 2026? | KXMNDAYCARECHARGE
# Will the President sign more than 0 Executive Orders between Dec 28, 2025 and Jan 3, 2026? | KXEOWEEK-26JAN03
# What will Bernie Sanders say during ceremonial inauguration at City Hall on January 1st? | KXBERNIEMENTION-26JAN02
# What will Zohran Mamdani say during ceremonial inauguration at City Hall on January 1st? | KXMAMDANIMENTION-26JAN02
# Will Daisies be Top 10 on the Billboard Hot 100 chart for the week of January 10, 2026? | KXRANKLISTSONGTOP10-26JAN10
# Will average **gas prices** be above $2.825? | KXAAAGASW-26JAN05
# Will more than 1800000 people be **screened by the TSA** on average this week? | KXTSAW-26JAN04
# Will Trump release any documents about Epstein's associates before Jan 4, 2026? | KXEPSTEIN-26JAN04
# Will Trump say "Autopen / Auto Pen" before Jan 5, 2026? | KXTRUMPSAY-26JAN05
# Will the WTI front-month settle oil price  be Between 51 and 51.99 on Jan 2, 2026?? | KXWTIW-26JAN02
# Getafe at Vallecano: Both Teams to Score | KXLALIGABTTS-26JAN02RVCGET
# Lens at Toulouse: Both Teams to Score | KXLIGUE1BTTS-26JAN02TFCRCL
# Getafe at Vallecano: Totals | KXLALIGATOTAL-26JAN02RVCGET
# Lens at Toulouse: Totals | KXLIGUE1TOTAL-26JAN02TFCRCL
# Getafe wins by over 1.5 goals? | KXLALIGASPREAD-26JAN02RVCGET
# Lens wins by over 1.5 goals? | KXLIGUE1SPREAD-26JAN02TFCRCL
# Ripple price at Jan 2, 2026 at 5pm EST? | KXXRP-26JAN0217
# Ripple price at Jan 2, 2026 at 5pm EST? | KXXRPD-26JAN0217
# SOL price  on Jan 2, 2026? | KXSOLD-26JAN0217
# Dogecoin price range  on Jan 2, 2026? | KXDOGE-26JAN0217
# SOL price  on Jan 2, 2026? | KXSOLE-26JAN0217
# Dogecoin price  on Jan 2, 2026? | KXDOGED-26JAN0217
# Bitcoin price range  on Jan 2, 2026? | KXBTC-26JAN0217
# Ethereum price at Jan 2, 2026 at 5pm EST? | KXETH-26JAN0217
# Ethereum price at Jan 2, 2026 at 5pm EST? | KXETHD-26JAN0217
# Bitcoin price  on Jan 2, 2026? | KXBTCD-26JAN0217
# Will the Nasdaq-100 be between 24200 and 24299.9900 at the end of Jan 2, 2026 at 4pm EST? | KXNASDAQ100-26JAN02H1600
# Will the S&P 500 be between 6575 and 6599.9999 on Jan 2, 2026 at 4pm EST? | KXINX-26JAN02H1600
# Will the yield of 10-year U.S. treasury notes be between 3.97 and 3.99 on Jan 2, 2026? | KXTNOTEW-26JAN02
# Billboard 200 #2 on Jan 10, 2026 chart? | KXBILLBOARDRUNNERUPALBUM-26JAN10
# Billboard Hot 100 #2 on Jan 10, 2026 chart? | KXBILLBOARDRUNNERUPSONG-26JAN10
# Billboard Top 200 #1 on Jan 10, 2026 chart? | KXTOPALBUM-26JAN10
# Will All I Want For Christmas Is You be the #1 song on the Billboard Hot 100 charts this week? | KXTOPSONG-26JAN10
# Who will feature on "Don't Be Dumb" by A$AP Rocky? | KXFEATUREASAPROCKY
# Return to Silent Hill Rotten Tomatoes score? | KXRTRETURNTOSILENTHILL
# Primate Rotten Tomatoes score? | KXRTPRIMATE
# Will A$AP Rocky release Don't Be Dumb before Jan 17, 2026? | KXALBUMRELEASEDATEASAP
# 2026 Best Animated Feature Film Oscar nominations? | KXOSCARNOMSBANIMATEDF-26
# What will Jensen Huang say during NVIDIA Live at CES 2026 with Founder and CEO Jensen Huang? | KXJENSENMENTION-26JAN06
# Tech layoffs up in Nov 2025? | KXTECHLAYOFF-25NOV
# Will the Bank of Japan Cut 25 basis points at the Jan 2026 BOJ meeting? | KXCBDECISIONJAPAN-26JAN22
# Will the House vote on any resolution impeaching Pamela Bondi? | KXVOTEBONDIIMPEACH
# Will Bari Weiss leave CBS before January 10, 2026? | KXBARIWEISSOUT-25DEC23
# Will 60 Minutes release Inside CECOT (or an equivalent renamed story largely about CECOT) before Feb 1, 2026? | KX60MCECOT
# 2026 Best Visual Effects Oscar nominations? | KXOSCARNOMVISUAL-26
# Will Actually Romantic be 1-100 on the Billboard Hot 100 chart for the week of January 10, 2026? | KXRANKLISTSONGBBH100-26JAN10
# Will CPI rise more than 0.0% in December 2025? | KXCPI-25DEC
# Will the rate of core CPI inflation be above 2.4% for the year ending in December 2025? | KXCPICOREYOY-25DEC
# Will egg prices rise by more than 0% in Dec 2025? | KXEGGS-DEC
# Will U3 be 4.3% AND NFP be >125k for Dec 2025? | KXEMPLOYMENTCOMBO-26JAN
# Will the unemployment rate (U-3) be above 3.8% in December? | KXU3-25DEC
# 28 Years Later: The Bone Temple Rotten Tomatoes score? | KXRT28YEARSLATERTBT
# 2026 Best Director Oscar nominations? | KXOSCARNOMDIR-26
# Will the White House Press Secretary say Affordable / Affordability at her next press briefing? | KXSECPRESSMENTION-26JAN30
# Will Powell say ADP at his Jan 2026 press conference? | KXFEDMENTION-26JAN
# Will Federal Funds Rates be No change AND Dissents be 0 for Jan 2026? | KXFEDCOMBO-26JAN
# How many dissenting votes at the next Fed meeting? | KXFOMCDISSENTCOUNT-26JAN
# The Legend of Heroes: Trails beyond the Horizon Metacritic score? | KXMCLOHTBTH
# Soulm8te Rotten Tomatoes score? | KXRTSOULM8TE
# We Bury the Dead Rotten Tomatoes score? | KXRTWEBURYTHEDEAD
# Will the rate of CPI inflation be above 2.4% for the year ending in December 2025? | KXCPIYOY-25DEC
# Will CPI be Above -0.1% AND YOYCPI be Above 2.4% for Dec 2025? | KXCPICOMBO-25DEC
# Will Trump announce his new Chair of the Federal Reserve in 2026? | KXPRESNOMFEDCHAIR-25
# Unemployment rate in Dec 2025? | KXECONSTATU3-25DEC
# CPI core year-over-year in Dec 2025? | KXECONSTATCORECPIYOY-25DEC
# CPI core month-over-month in Dec 2025? | KXECONSTATCPICORE-25DEC
# CPI year-over-year in Dec 2025? | KXECONSTATCPIYOY-25DEC
# CPI month-over-month in Dec 2025? | KXECONSTATCPI-25DEC
# 2026 Best Documentary Feature Film Oscar nominations? | KXOSCARNOMDOCU-26
# Will the rate of core PCE inflation be above 0.0% in December 2025? | KXPCECORE-25DEC
# ADP employment change in Dec 2025? | KXADP-25DEC
# Will above 0 jobs be added in December 2025? | KXPAYROLLS-25DEC
# Will Bank of Canada Cut rates by 25bps at their January 2026 meeting? | KXCBDECISIONCANADA-26JAN
# Will average **gas prices** be above $2.90? | KXAAAGASM-26JAN31
# UCL Bottom of Table | KXUCLBOTTOM-26
# UCL League Phase Winner | KXUCLTOP-26
# UCL League Phase Top 8 Finishers | KXUCLTOP8-26
# Will the Federal Reserve Cut rates by 25bps at their January 2026 meeting? | KXFEDDECISION-26JAN
# Will **real GDP** increase by more than 2.0% in Q4 2025? | KXGDP-26JAN30
# Tesla production in Q4 2025? | KXTESLAPROD-25-Q4
# How many Tesla deliveries will there be this quarter? | KXTESLA-25-Q4
# How many subscribers will Snapback Sports YouTube channel get in 2026 | KXYTUBESUBSSNAPBACK-26
# Who will Los Angeles D acquire this year? | KXACQUIRELADSKENES-25
# Will the upper bound of the federal funds rate be above 2.75% following the Fed's Jan 28, 2026 meeting? | KXFED-26JAN
# Will New York City rent grow above 0% in December 2025? | KXNYCRENTSY-25
# State of the economy at the end of 2025? | KXECONPATH-25
# Will ** coreinflation** in 2025 be above_below_between ? | KXCPICOREA-2025
# Will **inflation** in 2025 be above_below_between ? | KXACPI-2025
# GDP growth in 2025? | KXGDPYEAR-25
# How much will San Francisco rent grow by in ? | KXSFRENTSY-25
# How much will semiconductor production grow in the US this year? | KXSEMIPRODH-25
# Inflation surge in Dec 10, 2025? | KXLCPIMAXYOY-25

# %%
[market for market in liquid_markets if not is_sports_market(market)][100]
# Out:
# {'can_close_early': True,
#  'category': '',
#  'close_time': '2026-01-31T04:59:00Z',
#  'created_time': '2025-12-31T18:29:15.899062Z',
#  'event_ticker': 'KXAAAGASM-26JAN31',
#  'expected_expiration_time': '2026-01-31T15:00:00Z',
#  'expiration_time': '2026-02-07T15:00:00Z',
#  'expiration_value': '',
#  'floor_strike': 2.95,
#  'last_price': 7,
#  'last_price_dollars': '0.0700',
#  'latest_expiration_time': '2026-02-07T15:00:00Z',
#  'liquidity': 81045,
#  'liquidity_dollars': '810.4500',
#  'market_type': 'binary',
#  'no_ask': 93,
#  'no_ask_dollars': '0.9300',
#  'no_bid': 91,
#  'no_bid_dollars': '0.9100',
#  'no_sub_title': 'Above 2.95',
#  'notional_value': 100,
#  'notional_value_dollars': '1.0000',
#  'open_interest': 1364,
#  'open_time': '2025-12-31T22:00:00Z',
#  'previous_price': 22,
#  'previous_price_dollars': '0.2200',
#  'previous_yes_ask': 24,
#  'previous_yes_ask_dollars': '0.2400',
#  'previous_yes_bid': 17,
#  'previous_yes_bid_dollars': '0.1700',
#  'price_level_structure': 'linear_cent',
#  'price_ranges': [{'end': '1.0000', 'start': '0.0000', 'step': '0.0100'}],
#  'response_price_units': 'usd_cent',
#  'result': '',
#  'risk_limit_cents': 0,
#  'rules_primary': 'If average regular gas prices for United States are strictly greater than $2.95 on Jan 31, 2026 according to AAA,  the market resolves to Yes.',
#  'rules_secondary': '',
#  'settlement_timer_seconds': 3600,
#  'status': 'active',
#  'strike_type': 'greater',
#  'subtitle': '',
#  'tick_size': 1,
#  'ticker': 'KXAAAGASM-26JAN31-2.95',
#  'title': 'Will average **gas prices** be above $2.95?',
#  'volume': 1460,
#  'volume_24h': 1434,
#  'yes_ask': 9,
#  'yes_ask_dollars': '0.0900',
#  'yes_bid': 7,
#  'yes_bid_dollars': '0.0700',
#  'yes_sub_title': 'Above 2.95'}

# %%
x = [market for market in all_markets if market['event_ticker'].startswith('KXAAAGASM')]
print(len(x))

for xx in x:
    print(xx['title'])
# Out:
# 10
# Will average **gas prices** be above $2.95?
# Will average **gas prices** be above $2.70?
# Will average **gas prices** be above $2.75?
# Will average **gas prices** be above $2.80?
# Will average **gas prices** be above $2.85?
# Will average **gas prices** be above $3.30?
# Will average **gas prices** be above $3.20?
# Will average **gas prices** be above $3.10?
# Will average **gas prices** be above $3.00?
# Will average **gas prices** be above $2.90?
